# %%
import requests

def print_response(response):

    print("Encoding:", response.encoding)
    print("Status code:", response.status_code)
    print("URL:", response.url)
    print("Server Header:", response.headers['Server'])
    print("Headers:", response.headers)
    print("Content:", response.content)
    print("Text", response.text)
    
    try:
        print("JSON:", response.json())
    except requests.exceptions.JSONDecodeError:
        print("Response not in JSON format")

    print()

# HEAD
print('## HEAD ##')
resp = requests.head('https://httpbin.org/get')
print_response(resp)

# GET
print('## GET ##')
resp = requests.get('https://httpbin.org/get')
print_response(resp)

# POST
print('## POST ##')
resp = requests.post('https://httpbin.org/post', data={'key': 'value'})
print_response(resp)

# PUT
print('## PUT ##')
resp = requests.put('https://httpbin.org/put')
print_response(resp)

# DELETE
print('## DELETE ##')
resp = requests.delete('https://httpbin.org/delete')
print_response(resp)
# Out:
# ## HEAD ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/get
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:27:52 GMT', 'Content-Type': 'application/json', 'Content-Length': '308', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b''
# Text
# Response not in JSON format
#
# ## GET ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/get
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:27:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '308', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-66432e99-3e4526932612efe6562beded"\n  }, \n  "origin": "151.75.191.149", \n  "url": "https://httpbin.org/get"\n}\n'
# Text {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-66432e99-3e4526932612efe6562beded"
#   },
#   "origin": "151.75.191.149",
#   "url": "https://httpbin.org/get"
# }
#
# JSON: {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-66432e99-3e4526932612efe6562beded'}, 'origin': '151.75.191.149', 'url': 'https://httpbin.org/get'}
#
# ## POST ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/post
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:27:54 GMT', 'Content-Type': 'application/json', 'Content-Length': '480', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-66432e9a-35ef59a03b5858f746a0c50d"\n  }, \n  "json": null, \n  "origin": "151.75.191.149", \n  "url": "https://httpbin.org/post"\n}\n'
# Text {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-66432e9a-35ef59a03b5858f746a0c50d"
#   },
#   "json": null,
#   "origin": "151.75.191.149",
#   "url": "https://httpbin.org/post"
# }
#
# JSON: {'args': {}, 'data': '', 'files': {}, 'form': {'key': 'value'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '9', 'Content-Type': 'application/x-www-form-urlencoded', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-66432e9a-35ef59a03b5858f746a0c50d'}, 'json': None, 'origin': '151.75.191.149', 'url': 'https://httpbin.org/post'}
#
# ## PUT ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/put
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:27:54 GMT', 'Content-Type': 'application/json', 'Content-Length': '399', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-66432e9a-3b28fb830d30ff0d727cecf5"\n  }, \n  "json": null, \n  "origin": "151.75.191.149", \n  "url": "https://httpbin.org/put"\n}\n'
# Text {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-66432e9a-3b28fb830d30ff0d727cecf5"
#   },
#   "json": null,
#   "origin": "151.75.191.149",
#   "url": "https://httpbin.org/put"
# }
#
# JSON: {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '0', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-66432e9a-3b28fb830d30ff0d727cecf5'}, 'json': None, 'origin': '151.75.191.149', 'url': 'https://httpbin.org/put'}
#
# ## DELETE ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/delete
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:27:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '402', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-66432e9b-7ac52f7d17e08185096ff382"\n  }, \n  "json": null, \n  "origin": "151.75.191.149", \n  "url": "https://httpbin.org/delete"\n}\n'
# Text {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-66432e9b-7ac52f7d17e08185096ff382"
#   },
#   "json": null,
#   "origin": "151.75.191.149",
#   "url": "https://httpbin.org/delete"
# }
#
# JSON: {'args': {}, 'data': '', 'files': {}, 'form': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Content-Length': '0', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-66432e9b-7ac52f7d17e08185096ff382'}, 'json': None, 'origin': '151.75.191.149', 'url': 'https://httpbin.org/delete'}

# %%
# GET
print('## GET ##')
resp = requests.get('http://127.0.0.1:5000/users')
print_response(resp)

# %%
# GET with query string
print('## GET - 1 ##')
payload = {'key1': 'value1', 'key2': 'value2'}
resp = requests.get('https://httpbin.org/get', params=payload)
print_response(resp)

# GET with query string (multiple values for a key)
print('## GET - 2 ##')
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
resp = requests.get('https://httpbin.org/get', params=payload)
print_response(resp)
# Out:
# ## GET - 1 ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/get?key1=value1&key2=value2
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:31:04 GMT', 'Content-Type': 'application/json', 'Content-Length': '379', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-66432f58-0326b1fd66cd9c0c4aa5373a"\n  }, \n  "origin": "151.75.191.149", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2"\n}\n'
# Text {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-66432f58-0326b1fd66cd9c0c4aa5373a"
#   },
#   "origin": "151.75.191.149",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2"
# }
#
# JSON: {'args': {'key1': 'value1', 'key2': 'value2'}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-66432f58-0326b1fd66cd9c0c4aa5373a'}, 'origin': '151.75.191.149', 'url': 'https://httpbin.org/get?key1=value1&key2=value2'}
#
# ## GET - 2 ##
# Encoding: utf-8
# Status code: 200
# URL: https://httpbin.org/get?key1=value1&key2=value2&key2=value3
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:31:04 GMT', 'Content-Type': 'application/json', 'Content-Length': '422', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b'{\n  "args": {\n    "key1": "value1", \n    "key2": [\n      "value2", \n      "value3"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.31.0", \n    "X-Amzn-Trace-Id": "Root=1-66432f58-619cb8c0091827945ac1a29d"\n  }, \n  "origin": "151.75.191.149", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2&key2=value3"\n}\n'
# Text {
#   "args": {
#     "key1": "value1",
#     "key2": [
#       "value2",
#       "value3"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.31.0",
#     "X-Amzn-Trace-Id": "Root=1-66432f58-619cb8c0091827945ac1a29d"
#   },
#   "origin": "151.75.191.149",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2&key2=value3"
# }
#
# JSON: {'args': {'key1': 'value1', 'key2': ['value2', 'value3']}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.31.0', 'X-Amzn-Trace-Id': 'Root=1-66432f58-619cb8c0091827945ac1a29d'}, 'origin': '151.75.191.149', 'url': 'https://httpbin.org/get?key1=value1&key2=value2&key2=value3'}

# %%
# POST with multiple keys
print('## POST - 1 ##')
payload = {'key1': 'value1', 'key2': 'value2'}
resp = requests.post('https://httpbin.org/post', data=payload)
print_response(resp)

# POST with multiple values for a key
print('## POST - 2 ##')
payload_dict = {'key1': ['value1', 'value2']}
resp = requests.post('https://httpbin.org/post', data=payload_dict)
print_response(resp)
    
# POST with multiple values for a key (using list and tuples)
print('## POST - 3 ##')
resp = requests.get('https://api.github.com/events')
print_response(resp)

# %%
# Generate a bad response
resp = requests.get('https://httpbin.org/status/404')
print_response(resp)

# Check for error
resp.raise_for_status()
# Out:
# Encoding: utf-8
# Status code: 404
# URL: https://httpbin.org/status/404
# Server Header: gunicorn/19.9.0
# Headers: {'Date': 'Tue, 14 May 2024 09:31:46 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '0', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# Content: b''
# Text
# Response not in JSON format
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 print_response(resp)
#       5 # Check for error
# ----> 6 resp.raise_for_status()
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://httpbin.org/status/404
